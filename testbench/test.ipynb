# %% [markdown]
# ## **Inicialización banco de pruebas**
# ### *Comprobación separación de canales*
#
# Antes de comenzar con las pruebas es necesario asegurar que todo la configuración en términos de audio es correcta. Para ello, una vez se completa la conexión con la interfaz de audio se reproduce un sonido por cada uno de los auriculares, con el fin de identificar el receptor en cada caso.

# %%
from lib.helper import play_audio
INTRO = "res/beep.wav"
play_audio(INTRO, (1, -1))

# %%
from lib.helper import play_audio
INTRO = "res/beep.wav"
play_audio(INTRO, (-1, 1))
