# %%
from lib.helper import play_audio
INTRO = "res/beep.wav"
play_audio(INTRO, (1, -1))

# %%
from lib.helper import play_audio
INTRO = "res/beep.wav"
play_audio(INTRO, (-1, 1))
